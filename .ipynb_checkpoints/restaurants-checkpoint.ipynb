# %%
#importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
restaurant_data = pd.read_csv('chainness_point_2021_part1.csv')

# %%
#Looking at the first few values of the data frame
restaurant_data.head()
# Out:
#   RestaurantName     Cuisine  \
# 0         Subway  Restaurant
# 1         Subway  Restaurant
# 2         Subway  Restaurant
# 3         Subway  Restaurant
# 4         Subway  Restaurant
#
#                                            OpenHours State  CNTY_GEOID  \
# 0     Sun 900 AM  1100 PM | Mon  Sat 800 AM  1100 PM    OK       40143
# 1  Sun 1000 AM  730 PM | Mon  Fri 930 AM  830 PM ...    OH       39133
# 2                          Sun  Sat 1200 AM  1200 AM    IL       17031
# 3                           Sun  Sat 1000 AM  900 PM    AR        5085
# 4                                                NaN    IL       17031
#
#   CNTY_NAME  UA_GEOID          UA_NAME  MSA_GEOID  \
# 0     Tulsa   88948.0        Tulsa, OK    46140.0
# 1   Portage   17668.0    Cleveland, OH    10420.0
# 2      Cook   16264.0  Chicago, IL--IN    16980.0
# 3    Lonoke   50392.0  Little Rock, AR    30780.0
# 4      Cook   16264.0  Chicago, IL--IN    16980.0
#
#                                    MSA_NAME        Lon        Lat  Frequency  \
# 0                                 Tulsa, OK -95.855606  36.119330      24333
# 1                                 Akron, OH -81.348560  41.320137      24333
# 2        Chicago-Naperville-Elgin, IL-IN-WI -87.723145  41.775288      24333
# 3  Little Rock-North Little Rock-Conway, AR -92.009220  34.946293      24333
# 4        Chicago-Naperville-Elgin, IL-IN-WI -87.738870  41.657290      24333
#
#    isChain
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
